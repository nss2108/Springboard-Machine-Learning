# %%
import pandas as pd
import numpy as np

# %%
rng = pd.date_range('1/1/2011', periods=72, freq='H')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2011-01-01 00:00:00    0.490414
# 2011-01-01 01:00:00   -1.585257
# 2011-01-01 02:00:00   -1.413640
# 2011-01-01 03:00:00    0.573796
# 2011-01-01 04:00:00    0.893987
# 2011-01-01 05:00:00   -0.522036
# 2011-01-01 06:00:00    0.719072
# 2011-01-01 07:00:00    0.019527
# 2011-01-01 08:00:00    1.082733
# 2011-01-01 09:00:00    1.408296
# 2011-01-01 10:00:00   -0.336455
# 2011-01-01 11:00:00   -0.850698
# 2011-01-01 12:00:00    0.927263
# 2011-01-01 13:00:00    1.994543
# 2011-01-01 14:00:00    0.844197
# 2011-01-01 15:00:00   -1.180739
# 2011-01-01 16:00:00    0.038038
# 2011-01-01 17:00:00    0.237542
# 2011-01-01 18:00:00    0.902668
# 2011-01-01 19:00:00    2.989996
# 2011-01-01 20:00:00    0.493011
# 2011-01-01 21:00:00    0.283054
# 2011-01-01 22:00:00   -0.783139
# 2011-01-01 23:00:00   -0.896339
# 2011-01-02 00:00:00    0.024161
# 2011-01-02 01:00:00   -0.317787
# 2011-01-02 02:00:00   -0.033958
# 2011-01-02 03:00:00    0.556450
# 2011-01-02 04:00:00   -0.340698
# ...

# %%
converted = ts.asfreq('45Min', method="ffill")
converted
# Out:
# 2011-01-01 00:00:00    0.490414
# 2011-01-01 00:45:00    0.490414
# 2011-01-01 01:30:00   -1.585257
# 2011-01-01 02:15:00   -1.413640
# 2011-01-01 03:00:00    0.573796
# 2011-01-01 03:45:00    0.573796
# 2011-01-01 04:30:00    0.893987
# 2011-01-01 05:15:00   -0.522036
# 2011-01-01 06:00:00    0.719072
# 2011-01-01 06:45:00    0.719072
# 2011-01-01 07:30:00    0.019527
# 2011-01-01 08:15:00    1.082733
# 2011-01-01 09:00:00    1.408296
# 2011-01-01 09:45:00    1.408296
# 2011-01-01 10:30:00   -0.336455
# 2011-01-01 11:15:00   -0.850698
# 2011-01-01 12:00:00    0.927263
# 2011-01-01 12:45:00    0.927263
# 2011-01-01 13:30:00    1.994543
# 2011-01-01 14:15:00    0.844197
# 2011-01-01 15:00:00   -1.180739
# 2011-01-01 15:45:00   -1.180739
# 2011-01-01 16:30:00    0.038038
# 2011-01-01 17:15:00    0.237542
# 2011-01-01 18:00:00    0.902668
# 2011-01-01 18:45:00    0.902668
# 2011-01-01 19:30:00    2.989996
# 2011-01-01 20:15:00    0.493011
# 2011-01-01 21:00:00    0.283054
# ...

# %%
print(converted.shape)
ts.shape# Does asfreq change the # of rows?
"yes"
# Out:
# (95,)
# (72,)

# %%
"backfill/bfill are the same"
"pad and ffill are the same"
"None gives you Nans"
# What do the different methods do?
# method : {‘backfill’, ‘bfill’, ‘pad’, ‘ffill’, None}

# %%
# Might any of these methods have pitfalls from a logical point of view?
"forecasting the future from forward fill"

# %%
# What's the difference between going to a higher frequency and a lower frequency?
expands data versus collapsing data

# %%
converted = ts.asfreq('90Min', method = 'bfill')
converted
# Out:
# 2011-01-01 00:00:00    0.490414
# 2011-01-01 01:30:00   -1.413640
# 2011-01-01 03:00:00    0.573796
# 2011-01-01 04:30:00   -0.522036
# 2011-01-01 06:00:00    0.719072
# 2011-01-01 07:30:00    1.082733
# 2011-01-01 09:00:00    1.408296
# 2011-01-01 10:30:00   -0.850698
# 2011-01-01 12:00:00    0.927263
# 2011-01-01 13:30:00    0.844197
# 2011-01-01 15:00:00   -1.180739
# 2011-01-01 16:30:00    0.237542
# 2011-01-01 18:00:00    0.902668
# 2011-01-01 19:30:00    0.493011
# 2011-01-01 21:00:00    0.283054
# 2011-01-01 22:30:00   -0.896339
# 2011-01-02 00:00:00    0.024161
# 2011-01-02 01:30:00   -0.033958
# 2011-01-02 03:00:00    0.556450
# 2011-01-02 04:30:00    1.494356
# 2011-01-02 06:00:00    0.258301
# 2011-01-02 07:30:00   -1.113326
# 2011-01-02 09:00:00   -0.732484
# 2011-01-02 10:30:00   -0.218866
# 2011-01-02 12:00:00    1.255539
# 2011-01-02 13:30:00    0.953889
# 2011-01-02 15:00:00    1.187361
# 2011-01-02 16:30:00   -0.373037
# 2011-01-02 18:00:00    0.031579
# ...

# %%
# What's different logically about going to a higher frequency vs a lower frequency? 
# What do you want to do when switching to a lower freqeuncy that is not logical when switching to a higher frequency?

# %%
ts.resample('D').sum()
ts.resample("W").mean()
# Out:
# 2011-01-02    0.230358
# 2011-01-09    0.175378
# Freq: W-SUN, dtype: float64

# %%
you can keep nans# What if you want to downsample and you don't want to ffill or bfill?

# %%
'one gives you an object afterwards, whereas the other just reimposes a particular order on the dataset"# What is the difference between .resample() and .asfreq()?

# %%
"aggregative functions"# What are some special things you can do with .resample() you can't do with .asfreq()?
